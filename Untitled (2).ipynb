# %%
print("Hello")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('RavdessAudioOnlyFeatures_TEST.csv')
df
# Out:
#        modality vocal_channel  emotion emotional_intensity  \
# 0    audio-only        speech  neutral              normal
# 1    audio-only        speech  neutral              normal
# 2    audio-only        speech  neutral              normal
# 3    audio-only        speech  neutral              normal
# 4    audio-only        speech     calm              normal
# ..          ...           ...      ...                 ...
# 619  audio-only          song  fearful              normal
# 620  audio-only          song  fearful              strong
# 621  audio-only          song  fearful              strong
# 622  audio-only          song  fearful              strong
# 623  audio-only          song  fearful              strong
#
#                         statement repetition  actor sex  \
# 0    Kids are talking by the door        1st     19   M
# 1    Kids are talking by the door        2nd     19   M
# 2    Dogs are sitting by the door        1st     19   M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Columns: 434 entries, modality to stft_skew_w4
# dtypes: float64(405), int64(21), object(8)
# memory usage: 2.1+ MB

# %%
s=df.columns.tolist()
for i in s:
    print(df[i].value_counts())
# Out:
# audio-only    624
# Name: modality, dtype: int64
# speech    360
# song      264
# Name: vocal_channel, dtype: int64
# sad          96
# angry        96
# calm         96
# happy        96
# fearful      96
# surprised    48
# neutral      48
# disgust      48
# Name: emotion, dtype: int64
# normal    336
# strong    288
# Name: emotional_intensity, dtype: int64
# Kids are talking by the door    312
# Dogs are sitting by the door    312
# Name: statement, dtype: int64
# 1st    312
# 2nd    312
# Name: repetition, dtype: int64
# 24    104
# 23    104
# 22    104
# 21    104
# 20    104
# 19    104
# Name: actor, dtype: int64
# M    312
# F    312
# Name: sex, dtype: int64
# 03-02-02-02-02-02-19.wav    1
# 03-01-03-01-01-01-23.wav    1
# 03-01-04-01-02-01-19.wav    1
# 03-01-06-02-02-01-21.wav    1
# 03-01-03-01-01-02-23.wav    1
#                            ..
# 03-01-02-01-01-01-21.wav    1
# 03-01-06-01-02-01-24.wav    1
# 03-01-07-01-02-02-22.wav    1
# ...

# %%
df.isna().count()
# Out:
# modality               624
# vocal_channel          624
# emotion                624
# emotional_intensity    624
# statement              624
#                       ...
# stft_q75_w4            624
# stft_q95_w4            624
# stft_q99_w4            624
# stft_kur_w4            624
# stft_skew_w4           624
# Length: 434, dtype: int64

# %%
df.groupby('emotion')['sex'].value_counts()
# Out:
# emotion    sex
# angry      F      48
#            M      48
# calm       F      48
#            M      48
# disgust    F      24
#            M      24
# fearful    F      48
#            M      48
# happy      F      48
#            M      48
# neutral    F      24
#            M      24
# sad        F      48
#            M      48
# surprised  F      24
#            M      24
# Name: sex, dtype: int64
